# %% [markdown]
# <a href="https://colab.research.google.com/github/chchannel/SAM-3D-Pose-Analyzer/blob/main/sam_3d_pose_analyzer_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SAM 3D Pose Analyzer - Google Colab Edition
# このノートブックでは、無料で強力な GPU を利用して、写真から 3D 人物ポーズを復元できます。
#
# ### 💡 使いかた
# 1. 以下のセルを順番に実行してください（プレイボタンを押すだけです）。
# 2. 最後に表示される **Gradio の公開リンク (URL)** をクリックして操作画面を開いてください。

# %%
# @title 1. 環境構築 (Setup - 決定版)
import os
import shutil

# 1. フォルダを掃除して /content に戻る
# %cd /content
if os.path.exists("SAM-3D-Pose-Analyzer"):
    shutil.rmtree("SAM-3D-Pose-Analyzer")

# 2. 最新の状態をクローン
# !git clone https://github.com/chchannel/SAM-3D-Pose-Analyzer.git
# %cd SAM-3D-Pose-Analyzer

# 3. Hugging Face ログイン
# !pip install -U huggingface_hub
from huggingface_hub import notebook_login
# トークンを再入力したくない場合は、以下をコメントアウトせずに実行
notebook_login()

# 4. 全自動セットアップ（30個以上の部品をすべて集めます）
# !bash setup_colab.sh

# %%
# @title 2. アプリの起動 (Run App)
# app/main.py を実行します
# !python app/main.py --share
